# %%
import nltk
from nltk import tokenize
from string import punctuation
import pandas as pd
import unidecode

ratings = pd.read_csv('datasets/avaliacoes.csv')
relevants_df = ratings[['review_text', 'polarity']].copy()

white_space_tokenizer = tokenize.WhitespaceTokenizer()
word_punct = tokenize.WordPunctTokenizer()
stemmer = nltk.RSLPStemmer()

todas_palavras = ' '.join(relevants_df['review_text'].tolist())
token_dataset = white_space_tokenizer.tokenize(todas_palavras)
palavras_irrelevantes = nltk.corpus.stopwords.words("portuguese")
palavras_irrelevantes_sem_acento = [unidecode.unidecode(palavra) for palavra in palavras_irrelevantes]

pontuacao = list()
for ponto in punctuation:
  pontuacao.append(ponto)

pontuacao_stopwords = pontuacao + palavras_irrelevantes + palavras_irrelevantes_sem_acento

frase_processada = list()
for avaliacao in relevants_df['review_text']:
  palavras_texto = white_space_tokenizer.tokenize(avaliacao)
  palavras_text_sem_pontuacao = word_punct.tokenize(' '.join(palavras_texto))
  palavras_text_sem_pontuacao_sem_acento = [unidecode.unidecode(palavra) for palavra in palavras_text_sem_pontuacao]
  
  avaliacao = avaliacao.lower()
  nova_frase = list()
  for palavra in palavras_text_sem_pontuacao_sem_acento:
    if palavra not in pontuacao_stopwords:
        try:
            nova_frase.append(stemmer.stem(palavra))
        except:
            print(palavra)
            # nova_frase.append(palavra)
  frase_processada.append(' '.join(nova_frase))

relevants_df["review_text"] = frase_processada


relevants_df.head(10)
relevants_df.to_csv('datasets/avaliacoes_tokenized.csv', index=False)
# Out:
# m
# o
# o
# .
# o
# o
# l
# a
# a
# a
# o
# r
# o
# l
# o
# !
# r
# o
# r
# !
# i
# o
# s
# o
# o
# o
# a
# r
# a
# s
# u
# o
# e
# o
# m
# o
# o
# o
# s
# m
# o
# l
# o
# A
# a
# a
# e
# A
# a
# e
# s
# s
# s
# s
# o
# s
# r
# m
# o
# o
# l
# o
# u
# r
# o
# a
# z
# e
# s
# a
# o
# o
# u
# s
# a
# u
# s
# o
# m
# I
# O
# O
# O
# M
# A
# E
# E
# A
# O
# A
# O
# O
# L
# i
# a
# o
# o
# e
# a
# o
# a
# o
# r
# e
# o
# o
# o
# e
# s
# E
# e
# a
# e
# s
# o
# i
# !
# o
# a
# a
# o
# g
# 6
# a
# 2
# m
# e
# a
# s
# p
# p
# 0
# r
# r
# !
# o
# a
# o
# s
# o
# s
# s
# r
# r
# u
# a
# e
# i
# e
# e
# o
# z
# o
# e
# r
# s
# o
# u
# e
# r
# r
# a
# o
# i
# e
# s
# m
# o
# E
# o
# a
# l
# m
# m
# o
# a
# !
# a
# e
# i
# a
# o
# s
# o
# a
# e
# i
# s
# a
# r
# a
# s
# s
# ?
# o
# m
# ?
# O
# o
# u
# s
# o
# o
# o
# o
# o
# s
# r
# o
# e
# u
# s
# o
# o
# o
# o
# a
# r
# a
# u
# a
# a
# u
# s
# u
# e
# r
# l
# o
# a
# s
# P
# s
# s
# e
# s
# w
# .
# m
# o
# m
# s
# o
# o
# s
# u
# o
# a
# t
# r
# a
# e
# u
# o
# o
# o
# s
# o
# m
# a
# m
# s
# s
# i
# 0
# s
# i
# a
# m
# m
# o
# m
# u
# a
# a
# o
# o
# i
# a
# l
# a
# a
# r
# e
# o
# a
# o
# m
# o
# o
# r
# e
# i
# m
# i
# r
# o
# e
# e
# s
# o
# u
# a
# o
# o
# r
# a
# i
# r
# a
# o
# o
# o
# a
# a
# u
# r
# o
# a
# 1
# 5
# s
# u
# o
# o
# a
# o
# l
# l
# o
# o
# s
# o
# o
# m
# u
# o
# r
# a
# s
# o
# e
# m
# m
# l
# l
# s
# a
# o
# o
# o
# a
# s
# o
# a
# m
# l
# m
# o
# o
# l
# r
# s
# s
# m
# s
# a
# a
# s
# s
# e
# l
# r
# r
# a
# a
# o
# o
# o
# o
# s
# e
# s
# m
# s
# o
# o
# !
# o
# o
# i
# s
# s
# i
# a
# i
# o
# r
# o
# i
# e
# o
# e
# e
# a
# o
# o
# s
# a
# a
# s
# a
# a
# o
# u
# i
# o
# o
# e
# o
# e
# e
# o
# a
# e
# p
# o
# 7
# m
# o
# o
# o
# e
# u
# o
# a
# t
# m
# o
# l
# r
# r
# a
# O
# o
# o
# r
# o
# o
# m
# n
# o
# e
# s
# s
# o
# o
# a
# a
# u
# s
# s
# o
# s
# s
# s
# r
# o
# o
# o
# e
# u
# a
# o
# o
# s
# u
# o
# a
# i
# o
# m
# a
# o
# r
# o
# s
# o
# l
# r
# X
# 0
# a
# o
# e
# a
# r
# X
# D
# i
# r
# a
# a
# a
# e
# e
# l
# i
# t
# v
# g
# 9
# i
# o
# u
# o
# m
# o
# o
# a
# o
# o
# r
# o
# .
# a
# s
# a
# a
# v
# g
# 9
# a
# a
# r
# a
# e
# o
# o
# o
# o
# u
# s
# s
# o
# m
# a
# s
# s
# u
# r
# o
# m
# s
# o
# a
# o
# s
# r
# e
# a
# m
# l
# o
# a
# e
# a
# O
# C
# E
# u
# m
# o
# o
# a
# O
# i
# o
# s
# a
# a
# o
# o
# o
# l
# r
# o
# o
# r
# o
# a
# o
# e
# a
# r
# o
# l
# a
# i
# o
# a
# o
# o
# o
# e
# e
# o
# o
# a
# a
# a
# o
# s
# u
# o
# e
# s
# a
# s
# m
# o
# s
# o
# e
# a
# a
# e
# o
# e
# s
# i
# o
# a
# 0
# 3
# a
# o
# o
# a
# 0
# 4
# i
# e
# a
# 8
# 4
# u
# e
# m
# i
# o
# e
# s
# o
# e
# e
# a
# u
# a
# s
# i
# e
# a
# o
# o
# e
# r
# o
# a
# 3
# 4
# a
# r
# o
# o
# o
# e
# a
# i
# e
# i
# o
# o
# e
# a
# o
# o
# o
# o
# i
# s
# u
# r
# o
# o
# s
# s
# s
# u
# a
# r
# i
# o
# o
# u
# 6
# s
# s
# a
# a
# e
# s
# a
# m
# o
# u
# s
# o
# l
# r
# o
# o
# o
# i
# e
# o
# i
# z
# o
# s
# s
# a
# 2
# s
# o
# a
# u
# e
# l
# o
# s
# m
# m
# o
# l
# o
# i
# e
# o
# O
# o
# a
# r
# o
# o
# u
# l
# r
# o
# m
# o
# i
# r
# e
# u
# a
# o
# o
# t
# s
# i
# o
# O
# S
# e
# M
# A
# o
# o
# o
# o
# r
# s
# o
# o
# r
# o
# a
# 0
# 0
# u
# s
# O
# M
# O
# E
# O
# O
# E
# O
# o
# l
# r
# r
# e
# o
# l
# o
# i
# o
# s
# o
# l
# i
# u
# r
# a
# a
# o
# o
# u
# s
# s
# o
# m
# l
# r
# e
# t
# o
# o
# s
# u
# e
# e
# r
# a
# o
# o
# a
# o
# o
# e
# e
# e
# o
# o
# o
# o
# r
# o
# o
# s
# m
# o
# m
# o
# a
# o
# z
# a
# a
# o
# e
# e
# m
# o
# s
# o
# m
# m
# o
# A
# a
# a
# m
# s
# l
# a
# p
# s
# s
# e
# r
# a
# s
# s
# a
# a
# a
# s
# i
# r
# d
# m
# o
# i
# s
# o
# s
# o
# m
# u
# o
# o
# s
# o
# r
# o
# e
# s
# a
# a
# a
# i
# o
# o
# r
# i
# o
# i
# e
# s
# m
# u
# o
# e
# e
# o
# m
# o
# e
# o
# e
# m
# e
# o
# m
# o
# r
# o
# s
# o
# i
# o
# o
# l
# e
# a
# a
# a
# a
# r
# a
# e
# a
# o
# e
# o
# e
# s
# m
# r
# e
# a
# s
# s
# s
# o
# a
# o
# o
# o
# r
# s
# m
# r
# l
# e
# o
# o
# m
# o
# z
# r
# a
# o
# e
# a
# o
# o
# o
# e
# a
# o
# o
# x
# o
# o
# m
# o
# a
# m
# a
# e
# a
# 2
# 2
# 7
# o
# r
# o
# m
# e
# a
# o
# u
# o
# o
# o
# o
# a
# r
# a
# o
# i
# O
# o
# m
# i
# o
# m
# o
# a
# e
# a
# a
# o
# o
# u
# m
# o
# e
# i
# m
# a
# m
# o
# o
# m
# m
# o
# r
# o
# a
# a
# o
# e
# o
# A
# S
# E
# 0
# S
# O
# R
# O
# A
# S
# E
# O
# U
# S
# S
# S
# M
# O
# O
# O
# E
# E
# L
# E
# R
# A
# A
# S
# O
# O
# I
# O
# S
# A
# S
# o
# e
# u
# i
# e
# e
# 0
# 0
# o
# o
# o
# o
# l
# o
# a
# r
# s
# r
# r
# m
# a
# a
# e
# o
# r
# o
# o
# o
# o
# o
# o
# u
# s
# o
# o
# o
# r
# r
# m
# o
# o
# r
# a
# i
# a
# m
# a
# o
# a
# r
# a
# i
# o
# a
# e
# .
# o
# u
# o
# i
# o
# e
# a
# m
# o
# i
# o
# o
# a
# a
# o
# a
# p
# e
# o
# o
# l
# i
# m
# o
# a
# o
# m
# a
# m
# o
# e
# o
# a
# r
# r
# r
# o
# a
# a
# s
# o
# o
# e
# u
# o
# o
# a
# z
# a
# o
# a
# o
# r
# a
# o
# R
# 7
# e
# i
# r
# E
# A
# E
# M
# E
# !
# a
# a
# o
# s
# s
# m
# s
# u
# a
# i
# i
# r
# s
# s
# a
# o
# i
# o
# i
# a
# s
# r
# t
# e
# r
# s
# !
# a
# r
# e
# e
# e
# s
# o
# s
# r
# r
# i
# o
# o
# x
# o
# m
# a
# o
# o
# u
# o
# e
# o
# o
# o
# i
# s
# s
# s
# e
# a
# a
# r
# e
# a
# r
# a
# s
# r
# o
# a
# O
# o
# o
# a
# m
# r
# o
# a
# A
# a
# e
# a
# a
# o
# i
# o
# i
# e
# o
# e
# z
# o
# e
# l
# c
# a
# u
# r
# o
# o
# e
# o
# o
# o
# o
# o
# o
# i
# o
# e
# o
# r
# i
# a
# o
# m
# l
# r
# o
# i
# s
# o
# e
# a
# r
# e
# a
# e
# o
# u
# a
# o
# o
# o
# a
# s
# w
# a
# e
# r
# m
# s
# o
# e
# o
# o
# s
# o
# s
# s
# c
# .
# o
# s
# a
# e
# o
# a
# u
# o
# a
# o
# o
# o
# s
# r
# o
# o
# m
# o
# s
# s
# s
# a
# o
# u
# s
# o
# a
# s
# s
# k
# O
# o
# e
# o
# O
# u
# y
# o
# o
# e
# e
# r
# o
# m
# a
# e
# o
# o
# r
# z
# o
# t
# l
# m
# O
# o
# e
# e
# e
# s
# o
# o
# o
# m
# e
# e
# o
# l
# o
# l
# e
# l
# o
# z
# a
# e
# o
# a
# 1
# 2
# 8
# e
# 6
# 3
# 8
# i
# o
# m
# o
# r
# o
# m
# m
# o
# r
# O
# O
# o
# o
# e
# e
# o
# o
# o
# o
# o
# l
# s
# e
# u
# o
# i
# a
# o
# a
# e
# o
# r
# o
# O
# o
# i
# l
# m
# a
# a
# a
# o
# o
# O
# o
# s
# m
# o
# o
# o
# s
# e
# o
# a
# o
# z
# a
# a
# i
# o
# o
# e
# a
# m
# z
# o
# a
# r
# a
# o
# a
# m
# a
# u
# s
# a
# s
# s
# a
# e
# a
# s
# a
# o
# o
# i
# o
# a
# u
# r
# o
# r
# r
# a
# a
# o
# a
# a
# u
# o
# u
# s
# a
# a
# o
# o
# o
# .
# s
# s
# s
# s
# s
# o
# k
# s
# s
# s
# i
# e
# s
# s
# o
# o
# m
# o
# s
# i
# o
# o
# o
# k
# o
# o
# a
# a
# a
# a
# a
# i
# m
# a
# O
# o
# o
# z
# s
# s
# !
# i
# o
# o
# a
# a
# r
# a
# m
# e
# .
# o
# o
# a
# o
# o
# m
# o
# o
# o
# a
# o
# e
# o
# s
# a
# r
# s
# a
# i
# o
# r
# e
# a
# r
# o
# o
# a
# 7
# o
# 6
# l
# o
# a
# e
# u
# s
# a
# a
# o
# a
# o
# o
# a
# a
# a
# r
# o
# o
# e
# a
# o
# q
# a
# e
# e
# a
# s
# i
# o
# e
# r
# o
# o
# o
# l
# e
# i
# u
# m
# o
# s
# m
# o
# E
# r
# u
# m
# s
# a
# o
# i
# e
# o
# o
# r
# t
# V
# x
# a
# r
# o
# m
# q
# z
# d
# s
# i
# o
# a
# i
# o
# a
# a
# a
# o
# o
# e
# q
# e
# o
# e
# A
# a
# a
# a
# r
# o
# e
# a
# .
# u
# s
# o
# m
# r
# o
# r
# a
# u
# s
# o
# o
# m
# o
# s
# s
# o
# o
# A
# B
# s
# s
# a
# o
# s
# o
# o
# o
# o
# o
# o
# o
# o
# o
# a
# o
# o
# s
# o
# s
# a
# a
# a
# a
# m
# o
# o
# e
# o
# a
# o
# a
# 0
# o
# m
# a
# o
# o
# e
# a
# o
# a
# o
# a
# o
# a
# a
# o
# a
# s
# s
# a
# o
# l
# i
# o
# o
# e
# o
# m
# o
# r
# o
# u
# s
# a
# a
# !
# o
# .
# l
# .
# n
# .
# a
# e
# .
# o
# O
# o
# o
# a
# t
# o
# 0
# 0
# i
# e
# e
# n
# e
# o
# a
# o
# O
# m
# a
# m
# o
# i
# e
# m
# o
# o
# o
# a
# a
# o
# e
# q
# e
# O
# E
# S
# A
# E
# E
# A
# E
# R
# L
# E
# S
# o
# e
# e
# o
# a
# a
# e
# l
# i
# 2
# o
# m
# o
# .
# s
# e
# s
# s
# a
# e
# !
# i
# e
# s
# o
# u
# s
# i
# o
# i
# s
# z
# o
# m
# e
# m
# i
# o
# a
# a
# o
# i
# o
# a
# s
# s
# r
# e
# o
# e
# o
# s
# s
# o
# e
# m
# .
# o
# o
# O
# o
# m
# a
# m
# n
# e
# a
# o
# m
# o
# 8
# o
# a
# e
# u
# s
# i
# a
# a
# 1
# m
# m
# a
# 2
# m
# i
# a
# o
# m
# o
# a
# a
# a
# u
# a
# a
# o
# i
# r
# r
# r
# m
# r
# r
# e
# s
# s
# O
# o
# i
# l
# o
# o
# o
# o
# a
# s
# r
# a
# u
# 3
# s
# i
# o
# !
# o
# o
# m
# s
# a
# o
# o
# i
# s
# r
# o
# s
# s
# u
# a
# o
# o
# a
# r
# a
# m
# s
# o
# l
# a
# a
# e
# o
# l
# a
# e
# e
# o
# e
# a
# e
# m
# o
# s
# s
# )
# s
# s
# r
# x
# n
# o
# e
# o
# o
# o
# a
# .
# i
# o
# i
# e
# o
# s
# o
# r
# a
# u
# e
# 0
# s
# o
# o
# s
# o
# u
# o
# a
# o
# o
# o
# i
# u
# r
# s
# i
# o
# o
# o
# m
# e
# z
# a
# .
# s
# a
# a
# s
# m
# o
# s
# s
# a
# a
# a
# z
# a
# o
# e
# u
# i
# e
# a
# a
# u
# r
# o
# i
# r
# a
# i
# e
# s
# s
# i
# o
# s
# s
# s
# o
# e
# a
# o
# m
# r
# a
# l
# o
# o
# o
# o
# o
# l
# l
# l
# .
# a
# m
# o
# e
# m
# e
# r
# e
# e
# e
# a
# o
# o
# o
# r
# a
# o
# o
# o
# i
# s
# a
# a
# s
# u
# l
# !
# s
# o
# o
# r
# o
# o
# O
# O
# A
# A
# V
# O
# U
# O
# A
# R
# m
# o
# o
# a
# e
# e
# r
# o
# r
# a
# o
# o
# o
# o
# o
# e
# a
# o
# o
# s
# i
# s
# o
# s
# o
# r
# m
# s
# e
# a
# a
# R
# 0
# a
# o
# o
# a
# R
# 9
# o
# o
# a
# e
# m
# o
# r
# a
# l
# z
# r
# e
# ,
# l
# o
# o
# o
# s
# a
# r
# o
# o
# a
# r
# m
# a
# a
# m
# a
# o
# m
# e
# s
# s
# m
# o
# e
# r
# o
# o
# m
# o
# e
# a
# o
# a
# O
# i
# m
# o
# o
# i
# s
# a
# r
# o
# O
# i
# .
# O
# O
# O
# o
# e
# a
# a
# .
# m
# u
# i
# o
# .
# O
# e
# o
# o
# e
# s
# r
# o
# m
# o
# u
# o
# r
# a
# a
# o
# i
# u
# a
# o
# i
# o
# a
# e
# m
# a
# o
# m
# o
# a
# z
# a
# a
# o
# a
# o
# !
# i
# r
# o
# l
# a
# o
# e
# a
# e
# o
# e
# u
# o
# i
# o
# a
# o
# a
# r
# a
# i
# o
# s
# a
# m
# E
# e
# a
# z
# o
# s
# s
# a
# o
# s
# s
# u
# r
# o
# L
# A
# s
# o
# o
# l
# a
# i
# o
# s
# o
# i
# e
# e
# e
# O
# r
# s
# a
# s
# o
# e
# a
# e
# a
# r
# o
# a
# o
# m
# e
# a
# e
# e
# e
# o
# s
# s
# m
# s
# m
# o
# i
# r
# r
# o
# O
# a
# A
# L
# s
# o
# s
# a
# s
# a
# a
# a
# s
# o
# O
# E
# e
# a
# m
# s
# a
# a
# s
# s
# e
# o
# o
# u
# o
# a
# o
# o
# m
# a
# o
# a
# a
# a
# m
# o
# o
# a
# i
# a
# o
# l
# o
# o
# o
# a
# e
# o
# o
# e
# u
# e
# m
# r
# a
# a
# s
# o
# o
# a
# e
# o
# o
# e
# o
# a
# o
# s
# o
# g
# u
# m
# o
# o
# o
# X
# o
# o
# s
# s
# a
# e
# c
# o
# o
# h
# a
# r
# c
# a
# r
# s
# r
# o
# r
# o
# a
# e
# a
# o
# a
# e
# e
# l
# a
# a
# r
# r
# o
# a
# r
# a
# a
# e
# l
# r
# a
# o
# s
# r
# o
# e
# r
# t
# a
# o
# o
# s
# i
# r
# s
# s
# a
# i
# o
# r
# m
# e
# m
# o
# e
# e
# m
# o
# a
# a
# o
# e
# e
# e
# l
# r
# .
# o
# e
# o
# o
# s
# s
# s
# u
# m
# s
# o
# i
# o
# r
# u
# m
# a
# a
# a
# e
# a
# o
# r
# r
# o
# o
# i
# o
# i
# a
# e
# o
# a
# m
# e
# o
# a
# o
# u
# m
# s
# o
# o
# o
# r
# m
# o
# o
# a
# a
# r
# l
# h
# l
# a
# e
# O
# o
# m
# m
# o
# e
# o
# r
# z
# a
# a
# o
# m
# o
# o
# a
# o
# i
# u
# o
# u
# s
# u
# o
# u
# s
# o
# s
# s
# a
# e
# e
# l
# a
# a
# z
# a
# a
# s
# a
# m
# o
# .
# o
# e
# o
# .
# o
# m
# .
# O
# o
# o
# o
# l
# r
# m
# a
# e
# O
# o
# o
# o
# s
# m
# q
# u
# o
# r
# E
# h
# r
# o
# r
# e
# e
# i
# s
# i
# e
# s
# r
# o
# o
# o
# u
# u
# a
# a
# a
# a
# o
# o
# r
# o
# u
# r
# r
# s
# a
# r
# s
# m
# a
# o
# o
# o
# o
# i
# s
# s
# s
# o
# o
# e
# o
# s
# s
# ,
# i
# o
# u
# r
# o
# s
# o
# r
# o
# o
# a
# a
# s
# s
# s
# s
# s
# o
# o
# o
# e
# e
# o
# a
# s
# o
# i
# o
# o
# a
# s
# a
# e
# s
# e
# m
# o
# o
# m
# .
# i
# o
# o
# o
# i
# q
# o
# r
# o
# r
# o
# O
# O
# E
# E
# A
# E
# M
# E
# A
# O
# M
# E
# A
# s
# s
# a
# a
# s
# o
# 6
# m
# x
# 6
# m
# x
# 1
# m
# o
# e
# a
# a
# i
# e
# u
# o
# o
# s
# i
# I
# E
# O
# O
# E
# U
# E
# S
# S
# S
# O
# i
# o
# i
# m
# a
# a
# c
# z
# s
# s
# a
# o
# o
# a
# 0
# e
# m
# o
# l
# a
# a
# 0
# 4
# 4
# O
# o
# m
# o
# u
# o
# o
# o
# m
# e
# s
# o
# o
# m
# o
# o
# o
# e
# e
# e
# a
# !
# i
# o
# i
# r
# s
# s
# i
# s
# o
# o
# a
# .
# a
# o
# e
# a
# a
# s
# o
# o
# o
# a
# a
# i
# o
# u
# o
# o
# o
# o
# o
# l
# s
# s
# s
# l
# O
# o
# o
# s
# s
# s
# a
# a
# a
# o
# o
# s
# s
# e
# o
# u
# o
# r
# a
# r
# o
# r
# o
# m
# a
# o
# s
# r
# e
# i
# a
# e
# m
# i
# i
# o
# o
# e
# m
# l
# a
# r
# o
# u
# e
# m
# l
# s
# e
# e
# r
# o
# e
# l
# a
# a
# o
# r
# s
# s
# a
# O
# o
# a
# a
# u
# e
# o
# i
# s
# l
# m
# o
# s
# e
# o
# e
# a
# o
# a
# o
# o
# a
# .
# .
# o
# o
# a
# m
# o
# u
# e
# a
# u
# s
# o
# o
# o
# O
# o
# m
# e
# a
# o
# o
# o
# o
# a
# e
# h
# r
# o
# l
# e
# h
# r
# m
# a
# a
# s
# o
# i
# o
# o
# a
# a
# o
# e
# m
# o
# m
# s
# s
# m
# a
# a
# o
# o
# r
# o
# O
# e
# o
# o
# r
# o
# o
# s
# o
# m
# o
# r
# o
# e
# i
# a
# u
# o
# o
# m
# o
# i
# o
# m
# s
# o
# o
# a
# a
# q
# a
# e
# o
# a
# s
# s
# o
# i
# r
# a
# r
# o
# a
# p
# l
# e
# .
# u
# s
# o
# l
# o
# m
# o
# e
# a
# o
# i
# .
# o
# o
# x
# o
# x
# .
# e
# r
# .
# z
# o
# o
# z
# s
# a
# o
# !
# o
# o
# a
# o
# i
# o
# a
# 3
# o
# i
# s
# o
# o
# I
# o
# q
# o
# o
# u
# s
# i
# E
# a
# b
# u
# s
# o
# s
# !
# o
# e
# r
# e
# o
# a
# a
# o
# o
# s
# i
# q
# i
# o
# o
# a
# i
# a
# e
# 3
# s
# m
# o
# s
# s
# o
# o
# a
# o
# a
# e
# o
# o
# e
# a
# l
# a
# e
# o
# s
# m
# a
# m
# l
# o
# a
# o
# s
# o
# e
# o
# o
# a
# o
# m
# o
# e
# a
# e
# i
# i
# e
# s
# S
# A
# r
# o
# o
# o
# o
# s
# m
# r
# o
# e
# r
# o
# o
# o
# a
# o
# s
# m
# r
# o
# a
# r
# r
# s
# s
# r
# e
# r
# o
# m
# e
# i
# a
# a
# s
# e
# m
# m
# A
# o
# r
# r
# o
# o
# a
# o
# s
# m
# a
# a
# 0
# s
# e
# o
# a
# a
# 0
# e
# e
# r
# o
# i
# s
# a
# p
# s
# e
# E
# i
# o
# a
# r
# o
# o
# a
# r
# a
# o
# o
# s
# s
# s
# o
# o
# o
# a
# a
# s
# r
# o
# o
# o
# e
# e
# o
# u
# o
# a
# o
# l
# a
# l
# r
# s
# l
# a
# k
# a
# a
# u
# o
# s
# s
# s
# o
# s
# e
# a
# a
# l
# o
# a
# o
# o
# l
# o
# e
# o
# u
# r
# s
# s
# s
# 1
# D
# o
# D
# A
# a
# a
# a
# o
# 8
# B
# s
# r
# 1
# B
# A
# e
# o
# o
# e
# r
# m
# r
# s
# 2
# O
# r
# e
# a
# z
# o
# e
# l
# s
# o
# s
# o
# o
# m
# e
# a
# r
# r
# a
# i
# r
# r
# V
# r
# o
# a
# a
# e
# r
# a
# e
# 8
# s
# s
# o
# r
# a
# e
# a
# l
# e
# o
# s
# s
# e
# o
# o
# o
# s
# s
# a
# r
# o
# s
# m
# a
# r
# a
# o
# o
# o
# 3
# e
# i
# e
# i
# r
# o
# O
# o
# o
# o
# e
# c
# s
# a
# a
# e
# a
# r
# e
# s
# s
# e
# s
# ,
# i
# e
# i
# .
# a
# o
# r
# r
# a
# e
# o
# o
# i
# o
# o
# )
# a
# a
# a
# e
# o
# a
# e
# i
# s
# a
# a
# o
# r
# o
# a
# a
# m
# r
# a
# r
# s
# 0
# n
# r
# a
# o
# i
# r
# m
# l
# u
# r
# a
# o
# e
# e
# a
# o
# e
# a
# a
# a
# .
# m
# o
# o
# a
# i
# a
# o
# .
# l
# m
# r
# o
# a
# s
# o
# e
# m
# o
# a
# r
# a
# o
# A
# a
# e
# a
# O
# e
# m
# e
# e
# e
# m
# e
# o
# o
# o
# o
# a
# o
# m
# t
# r
# r
# u
# r
# r
# l
# e
# s
# A
# a
# a
# a
# u
# o
# e
# i
# o
# o
# e
# o
# o
# m
# m
# r
# o
# a
# i
# o
# r
# a
# a
# s
# i
# v
# a
# 4
# 1
# e
# 7
# 2
# a
# e
# s
# a
# z
# v
# a
# b
# o
# s
# .
# e
# o
# a
# e
# a
# z
# a
# r
# a
# z
# u
# r
# s
# s
# o
# m
# m
# s
# o
# o
# o
# i
# o
# o
# o
# 1
# e
# s
# i
# 2
# i
# e
# 5
# 5
# 5
# m
# i
# a
# 5
# 0
# s
# i
# a
# u
# i
# a
# 1
# 3
# e
# 8
# 3
# m
# m
# l
# o
# o
# s
# s
# a
# z
# e
# i
# s
# s
# o
# o
# o
# o
# o
# s
# s
# m
# o
# o
# r
# a
# u
# o
# a
# o
# o
# o
# o
# e
# e
# a
# o
# 3
# s
# a
# a
# e
# a
# r
# r
# i
# s
# 3
# s
# m
# s
# a
# m
# z
# 7
# s
# o
# a
# .
# e
# s
# u
# r
# a
# a
# s
# o
# s
# a
# o
# o
# a
# r
# r
# r
# m
# m
# o
# .
# u
# s
# o
# e
# s
# a
# a
# O
# o
# m
# m
# u
# o
# 0
# s
# o
# o
# o
# o
# o
# m
# o
# e
# o
# l
# .
# o
# s
# .
# o
# e
# m
# m
# o
# e
# o
# a
# m
# o
# m
# a
# a
# e
# o
# !
# o
# a
# m
# a
# m
# e
# e
# o
# o
# o
# a
# e
# r
# o
# o
# a
# s
# a
# a
# a
# r
# e
# e
# a
# e
# a
# a
# o
# e
# e
# e
# r
# o
# o
# a
# i
# r
# z
# a
# r
# u
# b
# n
# o
# O
# S
# a
# e
# o
# o
# o
# o
# o
# o
# r
# e
# e
# 0
# s
# a
# o
# o
# a
# u
# o
# o
# a
# e
# e
# z
# s
# o
# m
# o
# r
# o
# r
# o
# a
# a
# e
# a
# o
# a
# a
# l
# d
# m
# e
# l
# e
# o
# o
# o
# m
# o
# m
# u
# o
# o
# o
# o
# e
# s
# i
# o
# i
# a
# s
# o
# a
# m
# e
# m
# o
# o
# o
# o
# m
# s
# a
# r
# o
# m
# o
# o
# a
# o
# m
# o
# o
# u
# o
# u
# o
# a
# a
# a
# m
# x
# e
# a
# s
# s
# m
# m
# O
# r
# r
# a
# o
# l
# r
# a
# u
# o
# 1
# s
# o
# 3
# s
# s
# m
# v
# u
# e
# u
# r
# p
# a
# a
# a
# u
# o
# 5
# s
# s
# a
# a
# a
# q
# e
# o
# o
# r
# e
# r
# m
# o
# o
# m
# o
# r
# o
# i
# o
# m
# u
# o
# a
# a
# i
# l
# s
# m
# u
# T
# a
# s
# i
# r
# e
# a
# u
# o
# o
# O
# o
# e
# s
# A
# a
# s
# o
# o
# A
# m
# o
# o
# m
# a
# u
# r
# u
# o
# i
# a
# e
# o
# r
# o
# r
# o
# i
# o
# u
# o
# a
# o
# r
# o
# r
# q
# a
# o
# o
# o
# o
# o
# s
# a
# i
# i
# a
# s
# a
# r
# p
# l
# r
# s
# l
# s
# o
# a
# a
# r
# o
# O
# o
# m
# s
# o
# a
# e
# a
# o
# a
# o
# r
# s
# o
# o
# a
# a
# r
# o
# o
# s
# s
# s
# s
# e
# a
# a
# l
# r
# m
# m
# s
# s
# e
# s
# s
# i
# r
# o
# o
# o
# 3
# s
# o
# .
# i
# a
# a
# o
# r
# o
# o
# s
# o
# O
# I
# O
# O
# E
# A
# i
# r
# q
# a
# a
# o
# s
# o
# m
# o
# m
# o
# s
# a
# i
# a
# l
# o
# m
# o
# e
# a
# o
# a
# s
# o
# i
# o
# o
# a
# a
# o
# O
# o
# m
# e
# o
# e
# o
# s
# 6
# s
# m
# o
# E
# o
# a
# o
# m
# r
# e
# a
# o
# o
# .
# a
# e
# .
# a
# a
# l
# r
# .
# a
# u
# o
# o
# o
# o
# o
# s
# i
# a
# e
# u
# o
# a
# e
# a
# r
# a
# i
# r
# o
# o
# e
# o
# a
# o
# z
# 8
# m
# m
# a
# e
# l
# a
# e
# a
# o
# r
# o
# a
# o
# o
# o
# s
# s
# a
# o
# o
# s
# e
# a
# i
# r
# a
# a
# i
# e
# o
# m
# r
# a
# m
# a
# a
# r
# r
# a
# r
# o
# s
# a
# a
# e
# a
# a
# o
# a
# e
# O
# n
# e
# i
# e
# i
# i
# o
# o
# o
# o
# o
# e
# a
# r
# o
# .
# O
# o
# o
# e
# o
# a
# m
# o
# r
# o
# a
# s
# a
# a
# r
# a
# i
# o
# o
# r
# o
# a
# i
# o
# u
# s
# a
# e
# o
# e
# o
# o
# o
# o
# u
# u
# s
# o
# E
# O
# O
# U
# M
# A
# A
# !
# m
# r
# o
# o
# u
# a
# i
# e
# s
# o
# l
# o
# O
# O
# m
# o
# O
# E
# O
# o
# o
# a
# o
# !
# i
# r
# o
# o
# l
# o
# s
# a
# a
# e
# o
# m
# .
# s
# 2
# s
# a
# u
# u
# .
# a
# s
# s
# .
# a
# a
# u
# o
# o
# o
# O
# e
# m
# a
# e
# o
# !
# A
# O
# E
# E
# E
# !
# o
# l
# m
# a
# e
# a
# u
# o
# e
# s
# a
# i
# e
# a
# a
# u
# i
# o
# o
# o
# .
# o
# o
# .
# u
# i
# a
# i
# s
# o
# o
# o
# a
# s
# s
# a
# r
# o
# u
# o
# o
# m
# o
# a
# o
# r
# e
# e
# a
# r
# a
# a
# l
# e
# a
# i
# i
# a
# s
# E
# o
# s
# s
# a
# i
# o
# o
# u
# s
# o
# !
# u
# s
# o
# m
# E
# o
# o
# o
# m
# o
# e
# o
# i
# o
# s
# m
# q
# m
# a
# 3
# j
# i
# s
# m
# o
# r
# e
# a
# o
# o
# a
# s
# e
# e
# s
# s
# s
# s
# m
# e
# r
# a
# o
# o
# a
# o
# i
# m
# a
# i
# s
# s
# o
# a
# a
# r
# s
# !
# e
# r
# 5
# s
# s
# s
# o
# s
# o
# s
# r
# o
# o
# o
# i
# i
# e
# 7
# 1
# 7
# e
# e
# l
# 2
# 1
# 8
# a
# u
# A
# s
# u
# o
# r
# r
# r
# o
# o
# o
# o
# i
# o
# r
# o
# s
# i
# e
# e
# o
# A
# e
# u
# o
# a
# e
# o
# e
# r
# o
# m
# s
# A
# s
# m
# o
# o
# o
# s
# r
# a
# o
# a
# u
# 2
# 0
# p
# o
# a
# a
# a
# z
# e
# o
# a
# m
# i
# l
# a
# a
# a
# O
# o
# o
# o
# l
# u
# m
# s
# e
# 7
# i
# o
# m
# m
# a
# r
# r
# r
# o
# r
# u
# r
# r
# o
# e
# a
# r
# r
# o
# m
# r
# o
# x
# z
# r
# a
# e
# o
# s
# s
# o
# a
# r
# a
# o
# a
# l
# o
# o
# a
# a
# m
# o
# s
# u
# a
# r
# r
# o
# o
# e
# r
# a
# r
# z
# a
# s
# o
# a
# a
# r
# o
# .
# o
# o
# .
# i
# s
# s
# l
# m
# a
# a
# a
# a
# e
# u
# e
# a
# r
# a
# z
# r
# a
# a
# e
# e
# e
# a
# .
# e
# s
# r
# e
# r
# r
# r
# .
# o
# l
# .
# o
# !
# A
# a
# t
# a
# e
# a
# s
# s
# s
# a
# e
# l
# o
# s
# o
# a
# a
# o
# o
# e
# y
# o
# o
# r
# o
# r
# o
# q
# e
# a
# i
# s
# a
# e
# e
# a
# o
# u
# i
# l
# s
# r
# a
# e
# a
# r
# a
# m
# a
# l
# e
# a
# a
# a
# o
# a
# s
# s
# i
# e
# s
# o
# r
# o
# q
# a
# i
# O
# o
# l
# r
# 3
# o
# j
# 1
# l
# a
# a
# o
# .
# a
# o
# e
# s
# a
# o
# o
# o
# r
# o
# a
# u
# s
# o
# l
# o
# o
# e
# A
# m
# o
# z
# e
# o
# o
# e
# a
# a
# r
# a
# D
# O
# e
# .
# o
# r
# a
# e
# i
# o
# o
# o
# s
# a
# a
# R
# 2
# 0
# 0
# e
# o
# o
# r
# o
# l
# r
# m
# r
# e
# o
# a
# a
# 2
# 0
# .
# O
# r
# r
# D
# e
# m
# s
# o
# r
# e
# r
# o
# o
# r
# o
# o
# o
# e
# a
# a
# m
# a
# a
# a
# o
# e
# o
# a
# r
# a
# o
# o
# o
# o
# u
# e
# s
# s
# s
# a
# e
# o
# a
# a
# s
# s
# i
# s
# e
# r
# o
# o
# m
# o
# u
# o
# r
# o
# s
# z
# s
# s
# i
# s
# s
# s
# s
# p
# i
# e
# i
# a
# a
# a
# a
# i
# r
# p
# E
# u
# r
# a
# o
# a
# s
# s
# p
# o
# r
# E
# a
# a
# s
# s
# s
# u
# 2
# s
# o
# a
# a
# a
# o
# o
# o
# a
# o
# o
# o
# r
# a
# i
# o
# o
# e
# o
# o
# l
# l
# o
# s
# a
# o
# o
# o
# o
# o
# o
# o
# r
# e
# o
# o
# a
# s
# r
# r
# o
# e
# o
# a
# 2
# o
# i
# o
# i
# o
# r
# r
# o
# e
# E
# e
# o
# o
# s
# P
# a
# a
# s
# .
# E
# m
# a
# a
# r
# o
# s
# a
# o
# o
# a
# i
# i
# o
# O
# O
# M
# A
# A
# U
# S
# S
# E
# E
# R
# A
# S
# O
# O
# M
# R
# E
# O
# O
# S
# S
# A
# S
# S
# E
# M
# M
# O
# E
# U
# I
# E
# R
# S
# S
# O
# P
# A
# S
# S
# O
# S
# O
# S
# M
# E
# I
# A
# R
# S
# E
# E
# M
# S
# o
# e
# o
# l
# O
# o
# m
# o
# e
# o
# r
# m
# o
# o
# i
# e
# a
# i
# o
# e
# e
# r
# a
# s
# o
# o
# m
# n
# e
# o
# o
# e
# o
# e
# l
# z
# e
# o
# e
# a
# P
# a
# r
# a
# R
# 9
# 9
# k
# o
# i
# a
# a
# l
# e
# r
# X
# e
# o
# a
# r
# e
# o
# 6
# s
# o
# r
# 6
# s
# o
# a
# a
# e
# e
# s
# e
# s
# s
# i
# i
# s
# e
# o
# s
# o
# 6
# s
# s
# o
# o
# e
# E
# z
# a
# i
# e
# 8
# B
# m
# m
# e
# e
# l
# o
# o
# a
# a
# a
# a
# e
# s
# E
# i
# r
# o
# a
# r
# e
# o
# o
# e
# r
# u
# o
# u
# e
# o
# a
# o
# a
# o
# o
# k
# i
# O
# o
# u
# o
# o
# m
# o
# o
# u
# 3
# s
# o
# s
# a
# a
# a
# s
# o
# o
# l
# r
# a
# A
# a
# a
# o
# o
# o
# s
# s
# A
# a
# a
# r
# a
# i
# a
# 8
# s
# e
# .
# n
# u
# s
# s
# q
# o
# o
# a
# l
# o
# i
# l
# o
# .
# m
# a
# r
# o
# a
# A
# a
# u
# o
# 1
# s
# m
# e
# o
# i
# r
# o
# o
# e
# i
# o
# !
# a
# q
# o
# o
# r
# e
# o
# a
# a
# s
# i
# o
# o
# .
# a
# r
# o
# a
# e
# a
# R
# r
# .
# a
# m
# a
# e
# a
# E
# e
# i
# u
# .
# u
# u
# o
# a
# a
# o
# l
# r
# 1
# .
# o
# e
# .
# o
# o
# o
# r
# o
# a
# o
# o
# a
# r
# a
# o
# m
# o
# s
# s
# m
# o
# o
# r
# o
# i
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 35
#      33 for palavra in palavras_text_sem_pontuacao_sem_acento:
#      34   if palavra not in pontuacao_stopwords:
# ---> 35       print(palavra[-1])
#      36       nova_frase.append(stemmer.stem(palavra))
#      37 frase_processada.append(' '.join(nova_frase))
#
# IndexError: string index out of range
